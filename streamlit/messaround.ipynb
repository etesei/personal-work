# %%
#make a dataframe with four columns, with one being a timestamp column
#and the other three being random numbers
import pandas as pd
import numpy as np
import datetime as dt
import random
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
#make a dataframe using pandas with four columns

def make_df():
    #make a list of random numbers
    randomlist = []
    for i in range(0,10):
        n = random.randint(1,30)
        randomlist.append(n)
    #make a list of dates
    start = dt.datetime(2019,1,1)
    end = dt.datetime(2019,1,10)
    dates = [start + dt.timedelta(days=x) for x in range(0,10)]
    #make a dataframe
    df = pd.DataFrame({'dates':dates,'random':randomlist})
    return df

df = make_df()
more_dates = df.head(5).dates.unique()
more_dates_df = df.copy().head(len(more_dates))
#set all more_dates_df values to be null
for col in more_dates_df.columns.values:
    more_dates_df[col] = np.nan 
more_dates_df['dates'] = more_dates
concat = pd.concat([df,more_dates_df])

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import os
import streamlit as st

#main script to find, manipulate, and story data
def get_file_paths(directory):
    paths = []
    for i in os.path(directory):
        paths.append(i)
    
    return paths

# %%
# Out:
# module

# %%
import os

def list_files_in_directory(directory):
    """List full file paths in the specified directory."""
    file_paths = []  # List to store file paths
    for root, dirs, files in os.walk(directory):
        for file in files:
            file_path = os.path.join(root, file)
            file_paths.append(file_path)
    return file_paths

# Directory to be searched; 'data' in the current directory
directory_to_search = 'data'

# Get the file paths
file_paths = list_files_in_directory(directory_to_search)


# Print the file paths
for path in file_paths:
    if '_data' in path:
        print(path)
# Out:
# data/tulia_data.xlsx
# data/bar_tulia_mercado_data.xlsx
# data/the_french_data.xlsx

# %%
from data_api import *
# Out:
# 2024-01-21 17:30:03.001 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
get_tidy_excel_data('data/bar_tulia_mercado_data.xlsx')
# Out:
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /Users/evan.tesei/personal-work/streamlit/data_api.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /Users/evan.tesei/personal-work/streamlit/data_api.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# Category       date Explanation of comps +/- 2%   \
# 0        2023-01-02                          NaN
# 1        2023-01-03                          NaN
# 2        2023-01-04                          NaN
# 3        2023-01-05                          NaN
# 4        2023-01-06                          NaN
# ..              ...                          ...
# 611      2023-11-01                          NaN
# 612      2023-11-02                          NaN
# 613      2023-11-03                          NaN
# 614      2023-11-04                          NaN
# 615      2023-11-05                          NaN
#
# Category  explanation_of_sales_variance_plus_minus_2percent  bar_covers  \
# 0                    lots of walkins, especially late night         NaN
# 1                                                       NaN         NaN
# 2         a lot of reservations to start and a lot of wa...         NaN
# 3         great weather and foot traffic contributed to ...         NaN
# 4                                                       NaN         NaN
# ..                                                      ...         ...
# 611                                                     NaN        44.0
# 612                                                     NaN        44.0
# 613                                                     NaN        77.0
# 614                                                     NaN        79.0
# 615                                                     NaN        27.0
#
# Category  bar_sales  comp_percent  comps_excluding_employee_comps  \
# 0               NaN           NaN                             NaN
# 1               NaN           NaN                             NaN
# 2               NaN           NaN                             NaN
# 3               NaN           NaN                             NaN
# 4               NaN           NaN                             NaN
# ..              ...           ...                             ...
# 611         2058.00      0.020005                           205.0
# 612         2839.80      0.016568                           275.5
# 613         3834.50      0.011193                           248.0
# 614         4253.26      0.020278                           505.0
# 615         1557.00      0.018979                           251.0
#
# Category  dinner_covers  dinner_ppa  dinner_sales  labor_dollar  lunch_covers  \
# 0                   NaN         NaN           NaN           NaN           NaN
# 1                   NaN         NaN           NaN           NaN           NaN
# 2                   NaN         NaN           NaN           NaN           NaN
# 3                   NaN         NaN           NaN           NaN           NaN
# 4                   NaN         NaN           NaN           NaN           NaN
# ..                  ...         ...           ...           ...           ...
# 611               178.0   45.012640       8012.25       3343.94          65.0
# 612               264.0   56.406818      14891.40       4014.68          50.0
# 613               372.0   52.200000      19445.44       4497.23          73.0
# 614               436.0   49.791720      21709.19       5050.09          74.0
# 615               206.0   44.775485       9223.75       3924.62          92.0
#
# Category  lunch_ppa  lunch_sales  takeout_sales  total_covers  \
# 0               NaN          NaN            NaN           NaN
# 1               NaN          NaN            NaN           NaN
# 2               NaN          NaN            NaN           NaN
# 3               NaN          NaN            NaN           NaN
# 4               NaN          NaN            NaN           NaN
# ..              ...          ...            ...           ...
# 611       34.390154      2235.36           69.5         243.0
# 612       34.746000      1737.30           37.0         314.0
# 613       37.143836      2711.50          323.5         445.0
# 614       43.169595      3194.55          180.5         510.0
# 615       43.491304      4001.20          116.0         298.0
#
# Category  total_net_sales  variance  labor_percent
# 0                     NaN       NaN            NaN
# 1                     NaN       NaN            NaN
# 2                     NaN       NaN            NaN
# 3                     NaN       NaN            NaN
# 4                     NaN       NaN            NaN
# ..                    ...       ...            ...
# 611              10247.61 -0.373475       0.326314
# 612              16628.70 -0.080498       0.241431
# 613              22156.94 -0.047903       0.202972
# 614              24903.74 -0.123612       0.202784
# 615              13224.95 -0.281665       0.296759
#
# [924 rows x 19 columns]

# %%
get_tidy_excel_data('data/the_french_data.xlsx')
# Out:
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/3314219964.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# Category       date                       Explanation of comps +/- 2%   \
# 0        2023-01-02  $310 Alcohol comps(guest recovery) $216 Specai...
# 1        2023-01-03                                                NaN
# 2        2023-01-04                                                NaN
# 3        2023-01-05                                                NaN
# 4        2023-01-06                                                NaN
# ..              ...                                                ...
# 597      2023-11-01                                                NaN
# 598      2023-11-02                                                NaN
# 599      2023-11-03                                                NaN
# 600      2023-11-04                                                NaN
# 601      2023-11-05                                                NaN
#
# Category explanation_of_sales_variance_plus_minus_2percent  CATERING SALES  \
# 0          Insanely busy lunch and 37 bottles sold all day             NaN
# 1                  Decent walk in traffic, Good wine sales             NaN
# 2                      pop at 7 pm, again great wine sales             NaN
# 3                                         Early dinner pop             NaN
# 4                 Best Lunch and Dinner sales of the week!             NaN
# ..                                                     ...             ...
# 597                                                    NaN            85.0
# 598                                                    NaN             0.0
# 599                                                    NaN          2325.0
# 600                                                    NaN             0.0
# 601                                                    NaN             0.0
#
# Category  TOTAL NET SALES (EXC CATERING)  TOTAL NET SALES (INC CATERING)  \
# 0                                    NaN                             NaN
# 1                                    NaN                             NaN
# 2                                    NaN                             NaN
# 3                                    NaN                             NaN
# 4                                    NaN                             NaN
# ..                                   ...                             ...
# 597                             10325.25                        10410.25
# 598                             13804.00                        13804.00
# 599                             30663.00                        32988.00
# 600                             26335.50                        26335.50
# 601                             15429.97                        15429.97
#
# Category  VARIANCE TO 2021  VARIANCE TO 2022  bar_covers  bar_sales  ...  \
# 0                      NaN               NaN         NaN        NaN  ...
# 1                      NaN               NaN         NaN        NaN  ...
# 2                      NaN               NaN         NaN        NaN  ...
# 3                      NaN               NaN         NaN        NaN  ...
# 4                      NaN               NaN         NaN        NaN  ...
# ..                     ...               ...         ...        ...  ...
# 597                    NaN         -0.266334        61.0    1579.75  ...
# 598                    NaN          0.098782        52.0    1760.00  ...
# 599                    NaN          0.006474        33.0     907.75  ...
# 600                    NaN          0.111777       101.0    2940.00  ...
# 601                    NaN          0.156175        70.0    2783.20  ...
#
# Category  dinner_ppa  dinner_sales  labor_dollar  labor_percent  lunch_covers  \
# 0                NaN           NaN           NaN            NaN           NaN
# 1                NaN           NaN           NaN            NaN           NaN
# 2                NaN           NaN           NaN            NaN           NaN
# 3                NaN           NaN           NaN            NaN           NaN
# 4                NaN           NaN           NaN            NaN           NaN
# ..               ...           ...           ...            ...           ...
# 597        61.939236       8919.25       3498.31            NaN          40.0
# 598        63.548780      10422.00       3907.78            NaN          89.0
# 599       100.177122      27148.00       3935.10            NaN          97.0
# 600        58.739706      19971.50       4058.50            NaN         133.0
# 601        55.768607       6803.77       4054.83            NaN         207.0
#
# Category  lunch_ppa  lunch_sales  takeout_sales  total_covers  total_net_sales
# 0               NaN          NaN            NaN           NaN              NaN
# 1               NaN          NaN            NaN           NaN              NaN
# 2               NaN          NaN            NaN           NaN              NaN
# 3               NaN          NaN            NaN           NaN              NaN
# 4               NaN          NaN            NaN           NaN              NaN
# ..              ...          ...            ...           ...              ...
# 597       35.150000       1406.0           42.0         184.0              NaN
# 598       38.000000       3382.0          117.0         253.0              NaN
# 599       36.237113       3515.0            0.0         368.0              NaN
# 600       47.849624       6364.0            0.0         473.0              NaN
# 601       41.672464       8626.2            0.0         329.0              NaN
#
# [903 rows x 23 columns]

# %%
def get_tidy_excel_data(file_path):

    """
    read in excel weekly tabs, create two dataframes -- one qualitative data and one quantitative data
    """
    
    excel_object = pd.ExcelFile(file_path)
    sheets = excel_object.sheet_names

    sheets = [item for item in sheets if not any(char.isalpha() for char in item)]

    sheet_df_list_quant = []
    sheet_df_list_qual = []


    for sheet in sheets:
        sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)

        #find the first row of data
        for i in range(10):
            non_null_count = sheet_ex_data.iloc[i].notnull().sum()
            if non_null_count > 3:  # arbitrary threshold to find the starting row
                data_start_row = i
                break
        # Displaying the first few rows of actual data
        
        sample_data_start = sheet_ex_data.iloc[data_start_row:]
        sample_data_start.head()

        #find the first column of data
        while sample_data_start.iloc[:, 0].isna().all():
            sample_data_start = sample_data_start.drop(sample_data_start.columns[0], axis=1)
        

        # We need to transpose the DataFrame to get dates as rows and categories as columns

        # Extracting the relevant data (excluding the total column for now)
        if file_path == 'data/tulia_data.xlsx':
            date_index_val = 0
        else:
            date_index_val = 1
        data = sample_data_start.iloc[date_index_val :-1, 0:-1].T

        # Setting the first row as the header and the first column as the index
        data.columns = data.iloc[0]
        data = data[1:]

        # Resetting the index to make the date a column
        data.reset_index(drop=True, inplace=True)

        #remove Weekly Totals
        data = data[data['DATE'] != 'WEEKLY TOTALS']


        # Melting the DataFrame to get a long format
        data_melted = data.melt(id_vars=["DATE"], var_name="Category", value_name="Value")
        def clean_date(x):
            try:
                if '//' in x:
                    return x.replace('//','/')
                else:
                    return x
            except:
                return x
        data_melted['DATE'] = data_melted['DATE'].apply(np.vectorize(clean_date))
        data_melted['DATE'] = pd.to_datetime(data_melted['DATE'])
        data_melted = data_melted[~data_melted['Category'].isnull()]

        #split out qualitative and quantitative dataframes
        exp_list = []
        for i in data_melted[~data_melted['Category'].isnull()].Category.unique():
            if 'Explanation' in i:
                exp_list.append(i)
            else:
                pass
        
        #split out qualitative and quantitative dataframes
        data_melted_qual = data_melted[data_melted['Category'].isin(exp_list)]
        data_melted_quant = data_melted[~data_melted['Category'].isin(exp_list)]

        data_melted_quant.loc[data_melted_quant['Value']=='19.445.44', 'Value'] = 19445.44
        data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
        data_melted_quant.loc[data_melted_quant['Value'] == 'a lot of birthdays', 'Value'] = np.nan

        data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)

        #take instances where the cateogry = '2022 Net Sales' and relable them Total Net Sales, with a year prior date value

        #if the lowercase value of the column Category == 2022 net sales then do something

        data_melted_quant.loc[data_melted_quant['Category'].str.lower() == '2022 net sales', 'DATE'] = data_melted_quant.loc[data_melted_quant['Category'].str.lower() == '2022 net sales', 'DATE'].apply(lambda x: x - timedelta(days=365))
        data_melted_quant.loc[data_melted_quant['Category'].str.lower() =='2022 net sales','Category'] = 'TOTAL NET SALES'


    #     #add data to list
        sheet_df_list_quant.append(data_melted_quant)
        sheet_df_list_qual.append(data_melted_qual)

        sheet_data_concat_quant = pd.concat(sheet_df_list_quant)
        sheet_data_concat_qual = pd.concat(sheet_df_list_qual)






        friendly_column_name_dict = {
        'LUNCH SALES': 'lunch_sales',
        'LUNCH COVERS': 'lunch_covers',
        'DINNER SALES': 'dinner_sales',
        'DINNER COVERS': 'dinner_covers',
        'BAR SALES': 'bar_sales',
        'BAR COVERS': 'bar_covers',
        'TAKEOUT SALES': 'takeout_sales',
        'TOTAL NET SALES': 'total_net_sales',
        'VARIANCE': 'variance',
        'Explanation of sales variance +/- 2%': 'explanation_of_sales_variance_plus_minus_2percent',
        'Total Covers': 'total_covers',
        'LUNCH PPA': 'lunch_ppa',
        'DINNER PPA': 'dinner_ppa',
        'COMPS (excluding employee comps)': 'comps_excluding_employee_comps',
        'Comp %': 'comp_percent',
        'Explanation of comps +/- 2%': 'explanation_of_comps_plus_minus_2percent',
        'LABOR $': 'labor_dollar',
        'LABOR %': 'labor_percent',
        'Labor $': 'labor_dollar',
        'Labor %': 'labor_percent'
        }

        # #adjust column names
        sheet_data_concat_quant['Category'] = sheet_data_concat_quant['Category'].replace(friendly_column_name_dict)
        sheet_data_concat_quant = sheet_data_concat_quant[~sheet_data_concat_quant['Category'].isnull()]
        sheet_data_concat_qual['Category'] = sheet_data_concat_qual['Category'].replace(friendly_column_name_dict)
        sheet_data_concat_qual = sheet_data_concat_qual[~sheet_data_concat_qual['Category'].isnull()]

        df_final = pd.concat([
        df.pivot(index='DATE', columns='Category', values='Value').reset_index() for df in [sheet_data_concat_qual.drop_duplicates(), sheet_data_concat_quant.drop_duplicates()]])
        # df_final = sheet_data_concat_quant.reset_index().pivot(index = 'DATE',columns = 'Category', values = 'Value').reset_index()
        #additional metrics
        df_final['labor_percent'] = df_final['labor_dollar']/df_final['total_net_sales']

        # #update the column names
        df_final = df_final.rename(columns = {'DATE': 'date',
        'Category':'category',
        'Value': 'value'
        })




    return df_final

# %%
for file_path in ['data/tulia_data.xlsx',
                  'data/the_french_data.xlsx','data/bar_tulia_mercado_data.xlsx']:
    print(get_tidy_excel_data(file_path))
# Out:
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:17: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# Category       date Explanation of comps +/- 2%   \
# 0        2023-01-02                          NaN
# 1        2023-01-03                          NaN
# 2        2023-01-04                          NaN
# 3        2023-01-05                          NaN
# 4        2023-01-06                          NaN
# ..              ...                          ...
# 611      2023-11-01                          NaN
# 612      2023-11-02                          NaN
# 613      2023-11-03                          NaN
# 614      2023-11-04                          NaN
# 615      2023-11-05                          NaN
#
# Category  explanation_of_sales_variance_plus_minus_2percent  bar_covers  \
# 0                    lots of walkins, especially late night         NaN
# 1                                                       NaN         NaN
# 2         a lot of reservations to start and a lot of wa...         NaN
# 3         great weather and foot traffic contributed to ...         NaN
# 4                                                       NaN         NaN
# ..                                                      ...         ...
# 611                                                     NaN        44.0
# 612                                                     NaN        44.0
# 613                                                     NaN        77.0
# 614                                                     NaN        79.0
# 615                                                     NaN        27.0
#
# Category  bar_sales  comp_percent  comps_excluding_employee_comps  \
# 0               NaN           NaN                             NaN
# 1               NaN           NaN                             NaN
# 2               NaN           NaN                             NaN
# 3               NaN           NaN                             NaN
# 4               NaN           NaN                             NaN
# ..              ...           ...                             ...
# 611         2058.00      0.020005                           205.0
# 612         2839.80      0.016568                           275.5
# 613         3834.50      0.011193                           248.0
# 614         4253.26      0.020278                           505.0
# 615         1557.00      0.018979                           251.0
#
# Category  dinner_covers  dinner_ppa  dinner_sales  labor_dollar  lunch_covers  \
# 0                   NaN         NaN           NaN           NaN           NaN
# 1                   NaN         NaN           NaN           NaN           NaN
# 2                   NaN         NaN           NaN           NaN           NaN
# 3                   NaN         NaN           NaN           NaN           NaN
# 4                   NaN         NaN           NaN           NaN           NaN
# ..                  ...         ...           ...           ...           ...
# 611               178.0   45.012640       8012.25       3343.94          65.0
# 612               264.0   56.406818      14891.40       4014.68          50.0
# 613               372.0   52.200000      19445.44       4497.23          73.0
# 614               436.0   49.791720      21709.19       5050.09          74.0
# 615               206.0   44.775485       9223.75       3924.62          92.0
#
# Category  lunch_ppa  lunch_sales  takeout_sales  total_covers  \
# 0               NaN          NaN            NaN           NaN
# 1               NaN          NaN            NaN           NaN
# 2               NaN          NaN            NaN           NaN
# 3               NaN          NaN            NaN           NaN
# 4               NaN          NaN            NaN           NaN
# ..              ...          ...            ...           ...
# 611       34.390154      2235.36           69.5         243.0
# 612       34.746000      1737.30           37.0         314.0
# 613       37.143836      2711.50          323.5         445.0
# 614       43.169595      3194.55          180.5         510.0
# 615       43.491304      4001.20          116.0         298.0
#
# Category  total_net_sales  variance  labor_percent
# 0                     NaN       NaN            NaN
# 1                     NaN       NaN            NaN
# 2                     NaN       NaN            NaN
# 3                     NaN       NaN            NaN
# 4                     NaN       NaN            NaN
# ..                    ...       ...            ...
# 611              10247.61 -0.373475       0.326314
# 612              16628.70 -0.080498       0.241431
# 613              22156.94 -0.047903       0.202972
# 614              24903.74 -0.123612       0.202784
# 615              13224.95 -0.281665       0.296759
#
# [924 rows x 19 columns]
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/2106970343.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)

# %%
file_path = 'data/tulia_data.xlsx'

# %%
excel_object = pd.ExcelFile(file_path)
sheets = excel_object.sheet_names

sheets = [item for item in sheets if not any(char.isalpha() for char in item)]

sheet_df_list_quant = []
sheet_df_list_qual = []


for sheet in sheets:
    sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)

    #find the first row of data
    for i in range(10):
        non_null_count = sheet_ex_data.iloc[i].notnull().sum()
        if non_null_count > 3:  # arbitrary threshold to find the starting row
            data_start_row = i
            break
    # Displaying the first few rows of actual data
    
    sample_data_start = sheet_ex_data.iloc[data_start_row:]
    sample_data_start.head()

    #find the first column of data
    while sample_data_start.iloc[:, 0].isna().all():
        sample_data_start = sample_data_start.drop(sample_data_start.columns[0], axis=1)
    

    # We need to transpose the DataFrame to get dates as rows and categories as columns

    # Extracting the relevant data (excluding the total column for now)
    if file_path == 'data/tulia_data.xlsx':
        date_index_val = 0
    else:
        date_index_val = 1
    data = sample_data_start.iloc[date_index_val :-1, 0:-1].T

    # Setting the first row as the header and the first column as the index
    data.columns = data.iloc[0]
    data = data[1:]

    # Resetting the index to make the date a column
    data.reset_index(drop=True, inplace=True)

    #remove Weekly Totals
    data = data[data['DATE'] != 'WEEKLY TOTALS']


    # Melting the DataFrame to get a long format
    data_melted = data.melt(id_vars=["DATE"], var_name="Category", value_name="Value")
    def clean_date(x):
        try:
            if '//' in x:
                return x.replace('//','/')
            else:
                return x
        except:
            return x
    data_melted['DATE'] = data_melted['DATE'].apply(np.vectorize(clean_date))
    data_melted['DATE'] = pd.to_datetime(data_melted['DATE'])
    data_melted = data_melted[~data_melted['Category'].isnull()]

    #split out qualitative and quantitative dataframes
    exp_list = []
    for i in data_melted[~data_melted['Category'].isnull()].Category.unique():
        if 'Explanation' in i:
            exp_list.append(i)
        else:
            pass
    
    #split out qualitative and quantitative dataframes
    data_melted_qual = data_melted[data_melted['Category'].isin(exp_list)]
    data_melted_quant = data_melted[~data_melted['Category'].isin(exp_list)]

    data_melted_quant.loc[data_melted_quant['Value']=='19.445.44', 'Value'] = 19445.44
    data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
    data_melted_quant.loc[data_melted_quant['Value'] == 'a lot of birthdays', 'Value'] = np.nan

    data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)

    #take instances where the cateogry = '2022 Net Sales' and relable them Total Net Sales, with a year prior date value

    #if the lowercase value of the column Category == 2022 net sales then do something

    data_melted_quant.loc[data_melted_quant['Category'].str.lower() == '2022 net sales', 'DATE'] = data_melted_quant.loc[data_melted_quant['Category'].str.lower() == '2022 net sales', 'DATE'].apply(lambda x: x - timedelta(days=365))
    data_melted_quant.loc[data_melted_quant['Category'].str.lower() =='2022 net sales','Category'] = 'TOTAL NET SALES'


#     #add data to list
    sheet_df_list_quant.append(data_melted_quant)
    sheet_df_list_qual.append(data_melted_qual)

    sheet_data_concat_quant = pd.concat(sheet_df_list_quant)
    sheet_data_concat_qual = pd.concat(sheet_df_list_qual)






    friendly_column_name_dict = {
    'LUNCH SALES': 'lunch_sales',
    'LUNCH COVERS': 'lunch_covers',
    'DINNER SALES': 'dinner_sales',
    'DINNER COVERS': 'dinner_covers',
    'BAR SALES': 'bar_sales',
    'BAR COVERS': 'bar_covers',
    'TAKEOUT SALES': 'takeout_sales',
    'TOTAL NET SALES': 'total_net_sales',
    'VARIANCE': 'variance',
    'Explanation of sales variance +/- 2%': 'explanation_of_sales_variance_plus_minus_2percent',
    'Total Covers': 'total_covers',
    'LUNCH PPA': 'lunch_ppa',
    'DINNER PPA': 'dinner_ppa',
    'COMPS (excluding employee comps)': 'comps_excluding_employee_comps',
    'Comp %': 'comp_percent',
    'Explanation of comps +/- 2%': 'explanation_of_comps_plus_minus_2percent',
    'LABOR $': 'labor_dollar',
    'LABOR %': 'labor_percent',
    'Labor $': 'labor_dollar',
    'Labor %': 'labor_percent'
    }

    # #adjust column names
    sheet_data_concat_quant['Category'] = sheet_data_concat_quant['Category'].replace(friendly_column_name_dict)
    sheet_data_concat_quant = sheet_data_concat_quant[~sheet_data_concat_quant['Category'].isnull()]
    sheet_data_concat_qual['Category'] = sheet_data_concat_qual['Category'].replace(friendly_column_name_dict)
    sheet_data_concat_qual = sheet_data_concat_qual[~sheet_data_concat_qual['Category'].isnull()]

    df_final = pd.concat([
    df.pivot(index='DATE', columns='Category', values='Value').reset_index() for df in [sheet_data_concat_qual.drop_duplicates(), sheet_data_concat_quant.drop_duplicates()]])
    # df_final = sheet_data_concat_quant.reset_index().pivot(index = 'DATE',columns = 'Category', values = 'Value').reset_index()
    #additional metrics
    df_final['labor_percent'] = df_final['labor_dollar']/df_final['total_net_sales']

    # #update the column names
    df_final = df_final.rename(columns = {'DATE': 'date',
    'Category':'category',
    'Value': 'value'
    })
# Out:
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:11: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   sheet_ex_data = pd.read_excel(file_path,usecols='A:J',sheet_name = sheet)
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].replace({'#DIV/0!': np.nan})
# /var/folders/3_/9l8k0s297fvfm4ymcnc68wkh0000gq/T/ipykernel_92022/1555243425.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_melted_quant['Value'] = data_melted_quant['Value'].astype(float)

# %%
file_path
# Out:
# 'data/tulia_data.xlsx'

# %%
# Out:
# True

# %%
sample_data_start.iloc[date_index_val :-1, 0:-1].T
# Out:
#                              0               1               2   \
# Unnamed: 0                 DATE  OT LUNCH SALES  OTLUNCH COVERS
# MONDAY      2023-10-30 00:00:00          2212.5              44
# TUESDAY     2023-10-31 00:00:00          2096.8              59
# WEDNESDAY   2023-11-01 00:00:00            2159              58
# THURSDAY    2023-11-02 00:00:00         3276.75              83
# FRIDAY      2023-11-03 00:00:00          4070.5              93
# SATURDAY    2023-11-04 00:00:00            4288             110
# SUNDAY      2023-11-05 00:00:00            4727              99
#
#                          3                 4         5          6   \
# Unnamed: 0  OT DINNER SALES  OT DINNER COVERS  BT SALES  BT COVERS
# MONDAY                 8554               125   2376.25         39
# TUESDAY            12150.01               220   2500.25         74
# WEDNESDAY            8165.5               132   1742.75         34
# THURSDAY           13668.75               175    3562.5         96
# FRIDAY                22070               331   7329.65        188
# SATURDAY           19584.01               308  11040.25        148
# SUNDAY               9942.5               177      2035         46
#
#                            7                   8                9   ...  \
# Unnamed: 0  TO/Delivery Sales  TO/Delivery Orders  TOTAL NET SALES  ...
# MONDAY                    296                   7         13142.75  ...
# TUESDAY                     8                   1         16747.06  ...
# WEDNESDAY                 340                   5         12067.25  ...
# THURSDAY                  395                   9            20508  ...
# FRIDAY                    367                   7         33470.15  ...
# SATURDAY                  346                   5         34912.26  ...
# SUNDAY                    556                   9          16704.5  ...
#
#                   11                                                 12  \
# Unnamed: 0  VARIANCE                                                NaN
# MONDAY     -0.333116  Started with 44 and finished with 125 in OT.  ...
# TUESDAY     0.124996  Halloween. The streets was active. A lot of fo...
# WEDNESDAY   -0.34454  Quiet day all around to be expected after holi...
# THURSDAY   -0.031941  ok Lunch and Dinner for OT. BT had a few big p...
# FRIDAY      0.174763  Solid day all around. Great weather. Over 80 w...
# SATURDAY    0.232861  NOT A TYPO!  BT started the night with a $1000...
# SUNDAY     -0.136354  Started with a little over 100 covers. Saw a l...
#
#                       13            14             15         16  \
# Unnamed: 0  TOTAL COVERS  OT LUNCH PPA  OT DINNER PPA     BT PPA
# MONDAY               208     50.284091         68.432  60.929487
# TUESDAY              353     35.538983      55.227318  33.787162
# WEDNESDAY            224     37.224138      61.859848  51.257353
# THURSDAY             354     39.478916      78.107143  37.109375
# FRIDAY               612     43.768817      66.676737    38.9875
# SATURDAY             566     38.981818      63.584448  74.596284
# SUNDAY               322     47.747475      56.172316   44.23913
#
#                                                 17        18  \
# Unnamed: 0  TOTAL COMPS (excluding employee meals)    Comp %
# MONDAY                                         149  0.011337
# TUESDAY                                      258.7  0.015447
# WEDNESDAY                                       78  0.004237
# THURSDAY                                       187  0.008827
# FRIDAY                                       315.5  0.011074
# SATURDAY                                       320    0.0113
# SUNDAY                                       213.5  0.012781
#
#                                          19       20
# Unnamed: 0  Explanation of comps   \n+/- 2%  Labor $
# MONDAY                                  NaN  4101.59
# TUESDAY                                 NaN  4660.09
# WEDNESDAY                               NaN  4425.09
# THURSDAY                                NaN  5119.47
# FRIDAY                                  NaN  6175.97
# SATURDAY                                NaN  6223.01
# SUNDAY                                  NaN  4844.66
#
# [8 rows x 21 columns]

# %%
date_index_val = sample_data_start[sample_data_start[sample_data_start.columns.values[0]]=='DATE'].index.item() #get index of DATE value

# %%
data = sample_data_start.iloc[1 :-1, 0:-1].T

# %%
data
# Out:
#                              6            7             8             9   \
# Unnamed: 1                 DATE  LUNCH SALES  LUNCH COVERS  DINNER SALES
# Unnamed: 2  2023-10-30 00:00:00       1295.5          38.0        7615.2
# Unnamed: 3  2023-10-31 00:00:00       2110.0          52.0      10638.55
# Unnamed: 4  2023-11-01 00:00:00      2235.36          65.0       8012.25
# Unnamed: 5  2023-11-02 00:00:00       1737.3          50.0       14891.4
# Unnamed: 6  2023-11-03 00:00:00       2711.5          73.0     19.445.44
# Unnamed: 7  2023-11-04 00:00:00      3194.55          74.0      21709.19
# Unnamed: 8  2023-11-05 00:00:00       4001.2          92.0       9223.75
#
#                        10         11          12             13  \
# Unnamed: 1  DINNER COVERS  BAR SALES  BAR COVERS  TAKEOUT SALES
# Unnamed: 2          160.0     1646.5        28.0          145.5
# Unnamed: 3          227.0     2750.5        46.0          303.0
# Unnamed: 4          178.0     2058.0        44.0           69.5
# Unnamed: 5          264.0     2839.8        44.0           37.0
# Unnamed: 6          372.0     3834.5        77.0          323.5
# Unnamed: 7          436.0    4253.26        79.0          180.5
# Unnamed: 8          206.0     1557.0        27.0          116.0
#
#                          14              15        16  \
# Unnamed: 1  TOTAL NET SALES  2022 NET SALES  VARIANCE
# Unnamed: 2           8910.7        12307.14 -0.275973
# Unnamed: 3         12748.55         11094.7  0.149067
# Unnamed: 4         10247.61        16356.26 -0.373475
# Unnamed: 5          16628.7        18084.46 -0.080498
# Unnamed: 6         22156.94        23271.73 -0.047903
# Unnamed: 7         24903.74        28416.34 -0.123612
# Unnamed: 8         13224.95        18410.57 -0.281665
#
#                                               17            18         19  \
# Unnamed: 1  Explanation of sales variance +/- 2%  Total Covers  LUNCH PPA
# Unnamed: 2                                   NaN           198  34.092105
# Unnamed: 3                                   NaN           279  40.576923
# Unnamed: 4                                   NaN           243  34.390154
# Unnamed: 5                                   NaN           314     34.746
# Unnamed: 6                                   NaN           445  37.143836
# Unnamed: 7                                   NaN           510  43.169595
# Unnamed: 8                                   NaN           298  43.491304
#
#                     20                                21        22  \
# Unnamed: 1  DINNER PPA  COMPS (excluding employee comps)    Comp %
# Unnamed: 2      47.595                              86.0  0.009651
# Unnamed: 3   46.865859                             140.0  0.010982
# Unnamed: 4    45.01264                             205.0  0.020005
# Unnamed: 5   56.406818                             275.5  0.016568
# Unnamed: 6        52.2                             248.0  0.011193
# Unnamed: 7    49.79172                             505.0  0.020278
# Unnamed: 8   44.775485                             251.0  0.018979
#
#                                       23       24
# Unnamed: 1  Explanation of comps +/- 2%   LABOR $
# Unnamed: 2                           NaN  2912.51
# Unnamed: 3                           NaN  3332.85
# Unnamed: 4               Guest recovery   3343.94
# Unnamed: 5                           NaN  4014.68
# Unnamed: 6                           NaN  4497.23
# Unnamed: 7                           NaN  5050.09
# Unnamed: 8                           NaN  3924.62

# %%
data
# Out:
# 0  4101.59
# 1  4660.09
# 2  4425.09
# 3  5119.47
# 4  6175.97
# 5  6223.01
# 6  4844.66

# %%
sheet_data_concat_quant.groupby('DATE').count().plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
print(sheet_data_concat_quant[sheet_data_concat_quant.index.duplicated()])
# Out:
#           DATE      Category    Value
# 0   2023-10-23   lunch_sales  1876.50
# 1   2023-10-24   lunch_sales  1764.50
# 2   2023-10-25   lunch_sales  2000.86
# 3   2023-10-26   lunch_sales  1716.25
# 4   2023-10-27   lunch_sales  2664.69
# ..         ...           ...      ...
# 121 2023-01-04  labor_dollar  4167.96
# 122 2023-01-05  labor_dollar  5145.07
# 123 2023-01-06  labor_dollar  5395.41
# 124 2023-01-07  labor_dollar  5984.53
# 125 2023-01-08  labor_dollar  4883.92
#
# [4816 rows x 3 columns]

# %%
print(sheet_data_concat_quant.reset_index())
# Out:
#       index       DATE      Category    Value
# 0         0 2023-10-30   lunch_sales  1295.50
# 1         1 2023-10-31   lunch_sales  2110.00
# 2         2 2023-11-01   lunch_sales  2235.36
# 3         3 2023-11-02   lunch_sales  1737.30
# 4         4 2023-11-03   lunch_sales  2711.50
# ...     ...        ...           ...      ...
# 4923    121 2023-01-04  labor_dollar  4167.96
# 4924    122 2023-01-05  labor_dollar  5145.07
# 4925    123 2023-01-06  labor_dollar  5395.41
# 4926    124 2023-01-07  labor_dollar  5984.53
# 4927    125 2023-01-08  labor_dollar  4883.92
#
# [4928 rows x 4 columns]

# %%
test = sheet_data_concat_quant[~sheet_data_concat_quant['Category'].isnull()]

# %%
exp_list = []
for i in data_melted.Category.unique():
    if 'Explanation' in i:
        exp_list.append(i)
    else:
        pass

# %%
df_final
# Out:
# Category       DATE        Explanation of comps +/- 2%   \
# 0        2023-10-30  Special occasion and training food
# 1        2023-10-31                                 NaN
# 2        2023-11-01                                 NaN
# 3        2023-11-02                                 NaN
# 4        2023-11-03                                 NaN
# 5        2023-11-04                                 NaN
# 6        2023-11-05                                 NaN
# 0        2022-10-30                                 NaN
# 1        2022-10-31                                 NaN
# 2        2022-11-01                                 NaN
# 3        2022-11-02                                 NaN
# 4        2022-11-03                                 NaN
# 5        2022-11-04                                 NaN
# 6        2022-11-05                                 NaN
# 7        2023-10-30                                 NaN
# 8        2023-10-31                                 NaN
# 9        2023-11-01                                 NaN
# 10       2023-11-02                                 NaN
# 11       2023-11-03                                 NaN
# 12       2023-11-04                                 NaN
# 13       2023-11-05                                 NaN
#
# Category  explanation_of_sales_variance_plus_minus_2percent  CATERING SALES  \
# 0            Catering saved the day… lunch and dinner quiet             NaN
# 1         Large parties including 17 top, patio full, Ro...             NaN
# 2         Soft Lunch, Steady Dinner with good wine sales...             NaN
# 3                  Full Patio this evening, Rouge 14 covers             NaN
# 4                                   Rouge open. PM buyout.              NaN
# 5         Steady Lunch, early pop for dinner full restau...             NaN
# 6         Sunday Brunch started with  Rush and stayed bu...             NaN
# 0                                                       NaN             NaN
# 1                                                       NaN             NaN
# 2                                                       NaN             NaN
# 3                                                       NaN             NaN
# 4                                                       NaN             NaN
# 5                                                       NaN             NaN
# 6                                                       NaN             NaN
# 7                                                       NaN        10792.96
# 8                                                       NaN            0.00
# 9                                                       NaN           85.00
# 10                                                      NaN            0.00
# 11                                                      NaN         2325.00
# 12                                                      NaN            0.00
# 13                                                      NaN            0.00
#
# Category  TOTAL NET SALES (EXC CATERING)  TOTAL NET SALES (INC CATERING)  \
# 0                                    NaN                             NaN
# 1                                    NaN                             NaN
# 2                                    NaN                             NaN
# 3                                    NaN                             NaN
# 4                                    NaN                             NaN
# 5                                    NaN                             NaN
# 6                                    NaN                             NaN
# 0                                    NaN                             NaN
# 1                                    NaN                             NaN
# 2                                    NaN                             NaN
# 3                                    NaN                             NaN
# 4                                    NaN                             NaN
# 5                                    NaN                             NaN
# 6                                    NaN                             NaN
# 7                                6469.25                        17262.21
# 8                               12597.05                        12597.05
# 9                               10325.25                        10410.25
# 10                              13804.00                        13804.00
# 11                              30663.00                        32988.00
# 12                              26335.50                        26335.50
# 13                              15429.97                        15429.97
#
# Category  VARIANCE TO 2022  bar_covers  bar_sales  comp_percent  ...  \
# 0                      NaN         NaN        NaN           NaN  ...
# 1                      NaN         NaN        NaN           NaN  ...
# 2                      NaN         NaN        NaN           NaN  ...
# 3                      NaN         NaN        NaN           NaN  ...
# 4                      NaN         NaN        NaN           NaN  ...
# 5                      NaN         NaN        NaN           NaN  ...
# 6                      NaN         NaN        NaN           NaN  ...
# 0                      NaN         NaN        NaN           NaN  ...
# 1                      NaN         NaN        NaN           NaN  ...
# 2                      NaN         NaN        NaN           NaN  ...
# 3                      NaN         NaN        NaN           NaN  ...
# 4                      NaN         NaN        NaN           NaN  ...
# 5                      NaN         NaN        NaN           NaN  ...
# 6                      NaN         NaN        NaN           NaN  ...
# 7                -0.491081        46.0    1242.75      0.023805  ...
# 8                 0.580309        76.0    2522.00      0.011669  ...
# 9                -0.266334        61.0    1579.75      0.013656  ...
# 10                0.098782        52.0    1760.00      0.005433  ...
# 11                0.006474        33.0     907.75      0.016665  ...
# 12                0.111777       101.0    2940.00      0.013594  ...
# 13                0.156175        70.0    2783.20      0.013480  ...
#
# Category  dinner_ppa  dinner_sales  labor_dollar  labor_percent  lunch_covers  \
# 0                NaN           NaN           NaN            NaN           NaN
# 1                NaN           NaN           NaN            NaN           NaN
# 2                NaN           NaN           NaN            NaN           NaN
# 3                NaN           NaN           NaN            NaN           NaN
# 4                NaN           NaN           NaN            NaN           NaN
# 5                NaN           NaN           NaN            NaN           NaN
# 6                NaN           NaN           NaN            NaN           NaN
# 0                NaN           NaN           NaN            NaN           NaN
# 1                NaN           NaN           NaN            NaN           NaN
# 2                NaN           NaN           NaN            NaN           NaN
# 3                NaN           NaN           NaN            NaN           NaN
# 4                NaN           NaN           NaN            NaN           NaN
# 5                NaN           NaN           NaN            NaN           NaN
# 6                NaN           NaN           NaN            NaN           NaN
# 7          60.356164       4406.00       2845.10       0.164817          56.0
# 8          64.500298      10836.05       3641.90       0.289107          49.0
# 9          61.939236       8919.25       3498.31       0.336045          40.0
# 10         63.548780      10422.00       3907.78       0.283090          89.0
# 11        100.177122      27148.00       3935.10       0.119289          97.0
# 12         58.739706      19971.50       4058.50       0.154108         133.0
# 13         55.768607       6803.77       4054.83       0.262789         207.0
#
# Category  lunch_ppa  lunch_sales  takeout_sales  total_covers  total_net_sales
# 0               NaN          NaN            NaN           NaN              NaN
# 1               NaN          NaN            NaN           NaN              NaN
# 2               NaN          NaN            NaN           NaN              NaN
# 3               NaN          NaN            NaN           NaN              NaN
# 4               NaN          NaN            NaN           NaN              NaN
# 5               NaN          NaN            NaN           NaN              NaN
# 6               NaN          NaN            NaN           NaN              NaN
# 0               NaN          NaN            NaN           NaN         12711.75
# 1               NaN          NaN            NaN           NaN          7971.26
# 2               NaN          NaN            NaN           NaN         14073.50
# 3               NaN          NaN            NaN           NaN         12563.00
# 4               NaN          NaN            NaN           NaN         30465.76
# 5               NaN          NaN            NaN           NaN         23687.76
# 6               NaN          NaN            NaN           NaN         13345.70
# 7         36.843750      2063.25           20.0         129.0              NaN
# 8         35.938776      1761.00            0.0         217.0              NaN
# 9         35.150000      1406.00           42.0         184.0              NaN
# 10        38.000000      3382.00          117.0         253.0              NaN
# 11        36.237113      3515.00            0.0         368.0              NaN
# 12        47.849624      6364.00            0.0         473.0              NaN
# 13        41.672464      8626.20            0.0         329.0              NaN
#
# [21 rows x 22 columns]

# %%
len(sheets)
# Out:
# 45
